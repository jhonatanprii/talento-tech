# %%
nombre="Jhonatan"
apellido='Prieto'
edad= 17
peso= 98.5
cedula=True
print("Estudiante: " , nombre, apellido)
# Out:
# Estudiante:  Jhonatan Prieto

# %%
# condicional si (if)
if edad>=18:
    print("Esta habilitado para votar")
else:
    print("No esta habilitado para votar")
# Out:
# No esta habilitado para votar

# %%
nombres=["Jhonatan", "Yesenia" , "Andres", "Carlos"]
edades= [25, 26, 30, 40]
print(nombres[0])
print(edades[2])
# Out:
# Jhonatan
# 30

# %%
nombres[1]="Luisa"
print(nombres)
edades.insert(3,38)
print(edades)
# Out:
# ['Jhonatan', 'Luisa', 'Andres', 'Carlos']
# [25, 26, 30, 38, 38, 38, 38, 40]

# %%
nombres.append("luisa")

# %%
print(nombres)
# Out:
# ['Jhonatan', 'Luisa', 'Andres', 'Carlos', 'Luisa', 'Luis[1]']

# %%
edades.pop(2)
# Out:
# 38

# %%
print(edades)
# Out:
# [25, 30, 38, 38, 40]

# %%
# tuplas
coordenada=(75.25,245.56)
print(coordenada)
longitud=coordenada[0]
latitud=coordenada[1]
print("Esta es la Longitud", longitud)
print("Esta es la Latitud", latitud)
# Out:
# (75.25, 245.56)
# Esta es la Longitud 75.25
# Esta es la Latitud 245.56

# %%
nombre=input("Ingrese su nombre: ")
print("Hola: ", nombre)
edad=int(input("Ingrese su edad: "))
print("Su edad es: ", edad)

op=edad/7
print(f"{op:.2f}")
# Out:
# Ingrese su nombre: jhonatan
# Hola:  jhonatan
# Ingrese su edad: 29
# Su edad es:  29
# 4.14
