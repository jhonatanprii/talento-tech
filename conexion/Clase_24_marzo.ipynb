# %% [markdown]
# - convierteme la tabla en una matriz y reemplazame la primera columna con puros unos
# - dame la matriz traspuesta
# - sacame aparte la columna y como vector
# - multiplicame la traspuesta con la matriz
# - dame la invera de lo anterior
# - multiplicame lo anterior por la traspuesta por el vector de y
